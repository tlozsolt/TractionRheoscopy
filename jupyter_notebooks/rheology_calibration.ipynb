# %%
path = '/Users/zsolt/Dropbox/Colloid/Harvard/DATA/TractionForceRheology/tfrGel10212018x/gelCalibrationRheology'
fName = 'tfrGel09272018 (4).txt'

# %%
with open(path +'/{}'.format(fName)) as f:
    txt = f.readlines()

# %%
import pandas as pd
pd.from
# Out:
# ['Filename\ttfrGel09272018 (4)\n',
#  'Instrument name\t4010-0488\n',
#  'Operator\tZsolt\n',
#  'rundate\t9/30/2018\n',
#  'proceduresegments\tStandard Oscillatory Time Sweep#Frequency Sweep#Standard Oscillatory Amplitude Sweep\n',
#  '[File Parameters]\n',
#  'Name\ttfrGel09272018 (4)\n',
#  'Instrument type\tAresG2\n',
#  'Instrument serial number\t4010-0488\n',
#  'Instrument name\t4010-0488\n',
#  'Instrument location\tLab Room 520\n',
#  'Company name\tHarvard Univ\n',
#  'Trios version\t4.3.1.39215\n',
#  'File name\tC:\\Data\\Zsolt\\tfrGel09272018 (4).tri\n',
#  'Run date\t9/30/2018 2:35:31 PM\n',
#  'Time at start of test\t41.4458\n',
#  '[Firmware Versions]\n',
#  'InfoVerDsp\tV2018.2.13\n',
#  'InfoVerWinCe\tV2018.3.1\n',
#  'InfoVerPwr1\tV2017.1.11\n',
#  'InfoVerLincodr2\tV2017.1.11\n',
#  'InfoVerStepper3\tV2017.1.11\n',
#  'InfoVerMotorPrt4\tV2012.6.25\n',
#  'InfoVerXducerPrt5\tV2012.6.25\n',
#  'InfoVerPhaseFire6\tUnknown\n',
#  'InfoVerEnvironment7\tV2017.1.11\n',
# ...
